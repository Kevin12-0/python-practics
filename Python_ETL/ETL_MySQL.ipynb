# %%
#pip list

# %%
# import psycopg2 as py    Postgres
# import Pymssql          SQL Server
# pyodbc
# pyjdbc

import pymysql as py
import pandas as pd

# %%
# Conexión por Pymysql a Servidor Mysql
# Verificar que se tienen los Drivers instalados adecuadamente
try:    
     cnd = py.connect(
                  host     = '127.0.0.1', 
                  user     = 'root', 
                  password = 'Ekroku2K24',
                  database = 'superstore')
except:
    print ("No puedo conectarme a la DB, verifica por favor.")

# %%
# Leer archivo de SQL 
#SQLV1 = open('/home/rru/Desktop/Query_SQL.sql','r')

SQLV1 = 'select * from superstore'

# Generar conexión  a Pandas a través de SQL_Query
#DFAccounts = pd.read_sql_query(SQLV1,cnd)

#DFAccounts01 = pd.read_sql_query(SQLV1.read(),cnd)

DFsuper = pd.read_sql(SQLV1,cnd)
# Out:
# /tmp/ipykernel_3803/1908301077.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   DFsuper = pd.read_sql(SQLV1,cnd)

# %%
DFsuper
# Out:
#       RowID         OrderID   OrderDate    ShipDate        ShipMode  \
# 0         1  CA-2016-152156  2016-11-08  2016-11-11    Second Class
# 1         2  CA-2016-152156  2016-11-08  2016-11-11    Second Class
# 2         3  CA-2016-138688  2016-06-12  2016-06-16    Second Class
# 3         4  US-2015-108966  2015-10-11  2015-10-18  Standard Class
# 4         5  US-2015-108966  2015-10-11  2015-10-18  Standard Class
# ...     ...             ...         ...         ...             ...
# 9989   9990  CA-2014-110422  2014-01-21  2014-01-23    Second Class
# 9990   9991  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9991   9992  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9992   9993  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9993   9994  CA-2017-119914  2017-05-04  2017-05-09    Second Class
#
#      CustomerID      CustomerName    Segment        Country             City  \
# ...

# %% [markdown]
# # Conexión por Pymysql a Servidor Mysql
# # Verificar que se tienen los Drivers instalados adecuadamente
# try:
#      cnd2 = py.connect(
#             host   = '127.0.0.1',
#             user     = 'root',
#             password = 'Ekroku#2K24',
#             database = 'mysql')
# except:
#     print ("No puedo conectarme a la DB, verifica por favor.")

# %%
#Eliminar registros de tabla destino (sustitución - proceso previo)

cur = cnd.cursor()
try:
    cur.execute("delete from superstore")
    cnd.commit()
except:
    print ("No puedo ejecutar la consulta")
cur.close()

# %%
# Enviar datos de DF a Destino con SQLAlchemy

#Importar librerías de SQL Alchemy
from sqlalchemy import create_engine

#Conexión como parámetro DWH destino 
emy = create_engine('mysql+pymysql://root:Ekroku2K24@localhost:3306/superstore')
# mysql+pymysql

# %%
#Enviar datos de DF a Tablas OLAP

#DFProductos[['pk_producto','nombre_producto']].to_sql('dim_productos',epg, if_exists='append',index=False)

DFsuper.to_sql('superstore',emy, if_exists='append',index=False)
# Out:
# 9994

# %%
#DFUser.to_json('User.json')

# %%
DFsuper.to_parquet('superstore.parquet')

# %% [markdown]
# # Librerías para formato Parquet
#
# pip install pyarrow

# %% [markdown]
# # Librerías para formato Excel
#
# pip install xlrd

# %%
import pandas as pd

DFsuper = pd.read_excel('Superstore.xls')

# %%
DFsuper.to_csv('superstore.csv')
