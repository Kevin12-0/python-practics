# %% [markdown]
# # os

# %%
import os
import sys

# %% [markdown]
# ## get path

# %%
pwd = os.getcwd()
pwd
# Out:
# 'd:\\python-practics\\os'

# %% [markdown]
# ## convertir nombre de archivo a variable de entorno

# %%
file = "files/dataset.csv"
os.fsdecode(file)
# Out:
# 'files/dataset.csv'

# %% [markdown]
# ## Exeption for open the file

# %%
open(file)
# Out:
# <_io.TextIOWrapper name='files/dataset.csv' mode='r' encoding='cp1252'>

# %%
import io
io.open(file)
# Out:
# <_io.TextIOWrapper name='files/dataset.csv' mode='r' encoding='cp1252'>

# %% [markdown]
# ## Return the filename corresponding to the controlling terminal of the process.
# ## Only for UNIX

# %%
os.ctermid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\python-practics\os\notebook.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/python-practics/os/notebook.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> os.ctermid()
#
# AttributeError: module 'os' has no attribute 'ctermid'

# %% [markdown]
# ## Return Environment path

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\DELL\\AppData\\Roaming',
#         'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': '1',
#         'ASL.LOG': 'Destination=file',
#         'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey',
#         'CHOCOLATEYLASTPATHUPDATE': '133346996286458942',
#         'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_13884_KWKOIXPVPWWSRBNY',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'DESKTOP-ADUVVU0',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'EFC_15288': '1',
#         'ELECTRON_RUN_AS_NODE': '1',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\DELL',
#         'JPY_INTERRUPT_EVENT': '2168',
# ...

# %% [markdown]
# ## Acces an any environment variable of the system

# %%
os.environ["PATH"]
# Out:
# 'c:\\Users\\DELL\\AppData\\Local\\Programs\\Python\\Python311;c:\\Users\\DELL\\AppData\\Roaming\\Python\\Python311\\Scripts;C:\\Program Files (x86)\\Common Files\\Oracle\\Java\\javapath;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files (x86)\\NoteBook FanControl\\;C:\\Program Files (x86)\\Microsoft SQL Server\\110\\Tools\\Binn\\;C:\\Program Files (x86)\\Microsoft SQL Server\\110\\DTS\\Binn\\;C:\\Program Files\\Git\\cmd;C:\\Program Files\\nodejs\\;C:\\ProgramData\\chocolatey\\bin;C:\\Program Files\\MySQL\\MySQL Shell 8.0\\bin\\;C:\\Users\\DELL\\AppData\\Local\\Programs\\Python\\Python311\\Scripts\\;C:\\Users\\DELL\\AppData\\Local\\Programs\\Python\\Python311\\;C:\\Users\\DELL\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\DELL\\AppData\\Roaming\\npm;C:\\Users\\DELL\\AppData\\Local\\GitHubDesktop\\bin;C:\\Users\\DELL\\AppData\\Local\\Programs\\Microsoft VS Code Insiders\\
# ...

# %% [markdown]
# ## run other process or programs on the system

# %%
program = "python"
arguments = ["os.py"]

args_list = list(arguments)

os.execvp(program, args_list)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
